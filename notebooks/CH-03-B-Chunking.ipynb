# %% [markdown]
# # Reto 03-B-Chunking (Segmentación)

# %% [markdown]
# ## 1. Descripción General
#
# En este notebook, repasarás los conceptos de tokens y chunking. En el notebook anterior (`CH-03-A-Grounding`), pudimos proporcionar algo de contexto adicional para fundamentar el modelo. ¿Existe un límite para la cantidad de contexto adicional que podemos proporcionar al modelo? Desafortunadamente, la respuesta es sí. Existe un límite para la cantidad de tokens permitidos en la entrada y la salida combinadas según el modelo que se esté utilizando.
#
# Entonces, ¿qué son los tokens? Los tokens son una representación de cómo los modelos de Azure OpenAI procesan el texto. Son palabras o simplemente fragmentos de caracteres. Veamos el número total de tokens en la respuesta que obtuvimos del primer notebook del Desafío 3. Hay muchas formas de calcular tokens. En este notebook, echaremos un vistazo a la biblioteca `tiktoken` para contar los tokens.

# %% [markdown]
# ## 2. Comencemos con la Implementación
#
# Necesitarás importar los módulos necesarios. Las siguientes celdas son pasos de configuración de claves que ya completaste en los desafíos anteriores.

# %%
! pip install --upgrade click
! python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: click in /usr/local/python/3.12.1/lib/python3.12/site-packages (8.1.7)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 47.6 MB/s eta 0:00:0000:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.13.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10.0)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.27.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/python/3.12.1/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import openai
import PyPDF3
import os
import json
import tiktoken
import spacy
from openai.error import InvalidRequestError

from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

from spacy.lang.en import English 
nlp = spacy.load("en_core_web_sm")

import langchain
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# Configura tu entorno para acceder a tus claves de Azure OpenAI. Consulta tu recurso de Azure OpenAI en el Portal de Azure para obtener información sobre tu punto de conexión y claves de Azure OpenAI.
#
# Por razones de seguridad, almacena tu información sensible en un archivo .env.

# %%
# Load your OpenAI credentials
API_KEY = os.getenv("OPENAI_API_KEY")
assert API_KEY, "ERROR: Azure OpenAI Key is missing"
openai.api_key = API_KEY

RESOURCE_ENDPOINT = os.getenv("OPENAI_API_BASE","").strip()
assert RESOURCE_ENDPOINT, "ERROR: Azure OpenAI Endpoint is missing"
assert "openai.azure.com" in RESOURCE_ENDPOINT.lower(), "ERROR: Azure OpenAI Endpoint should be in the form: \n\n\t<your unique endpoint identifier>.openai.azure.com"
openai.api_base = RESOURCE_ENDPOINT

openai.api_type = os.getenv("OPENAI_API_TYPE")
openai.api_version = os.getenv("OPENAI_API_VERSION")
model=os.getenv("CHAT_MODEL_NAME")

# %% [markdown]
# ## 3. Conteo de Tokens
#
# `tiktoken` utiliza una técnica llamada codificación de pares de bytes (BPE) para convertir el texto dado en tokens. Hay diferentes codificaciones disponibles para ayudar a procesar las palabras. En este norebook, utilizaremos `cl100k_base`.
#
# #### Tarea #1 del Estudiante:
#
# Cuenta el número de tokens en la respuesta final que recibimos en `CH-03-A-Grounding` completando la función `count_tokens` a continuación.

# %%
def count_tokens(string: str, encoding_name: str) -> int:
    # Escribe el código aquí
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %% [markdown]
# #### Tarea #2 del Estudiante:
#
# Ingresa el texto de la respuesta que recibiste en `CH-03-A-Grounding`. Ejecuta la celda a continuación para recuperar el número de tokens utilizando la función `count_tokens`.

# %%
text = """Note: This information is fictional as it is set in the future.

The winner of the Wimbledon Tournament in 2023 for men's singles was Carlos Alcaraz."""

count_tokens(text, "cl100k_base")

print("There are " + str(count_tokens(text, "cl100k_base")) + " tokens: " + text)
# Out:
# There are 34 tokens: Note: This information is fictional as it is set in the future.
#
# The winner of the Wimbledon Tournament in 2023 for men's singles was Carlos Alcaraz.

# %% [markdown]
# Muy bien, ahora sabemos con cuántos tokens estamos trabajando. ¿Qué sucede si queremos agregar más contexto que el que ya pusimos en la variable de texto anterior? Si pensamos en nuestro escenario de Wimbledon, necesitaremos darle al modelo más contexto para ayudarlo a entender todo lo que necesita saber sobre el torneo. Más importante aún, todo lo que necesita saber para ayudar a responder tus preguntas al escribir el informe. Digamos que queremos proporcionar más contexto al modelo con un documento PDF. ¿Podemos intentar obtener un resumen del documento PDF para ayudarnos con nuestro trabajo?

# %% [markdown]
# #### Tarea #3 del Estudiante:
#
# En la celda siguiente, inserta la ruta del documento PDF, `CH3-data.pdf`, que se encuentra en la carpeta `/data` proporcionada. Ejecuta las tres celdas para ver la salida.

# %%
document = open(r'../data/CH3-data.pdf', 'rb') 
doc_helper = PyPDF3.PdfFileReader(document)

# %%
finaltext = ''
totalpages = doc_helper.getNumPages()
for eachpage in range(totalpages):
   p = doc_helper.getPage(eachpage)
   indpagetext = p.extractText()
   finaltext += indpagetext

clean_text = finaltext.replace("  ", " ").replace("\n", "; ").replace(';',' ')

# %%
prompt = f"What is the answer to the following question regarding the PDF document?\n\n{finaltext}\n\n" 
q = "Can you give me a summary of the document?"

try:
    final_prompt = prompt + q
    response = openai.ChatCompletion.create(engine=model, messages=final_prompt, max_tokens=50)
    answer = response.choices[0].text.strip()
    print(f"{q}\n{answer}\n")

except InvalidRequestError as e:
    print(e.error)
# Out:
# {
#   "code": null,
#   "message": "'What is the answer to the following question regarding the PDF document?\\n\\n \\nFormula 1 Power Unit Financial Regulations\\n \\n1\\n \\n16 August\\n \\n2022\\n \\n\u00a9 202\\n2\\n \\n\\n \\n \\n \\nIssue \\n1\\n \\n \\n \\n \\nFORMULA 1 \\nPOWER UNIT \\nFINANCIAL REGULATIONS\\n \\nPUBLISHED ON \\n16 August\\n \\n2022\\n \\nIssue \\n1\\n \\n \\nCONTENTS\\n \\n \\nArt\\n \\nCONTENTS\\n \\nPage(s)\\n \\n1.\\n \\nGENERAL PRINCIPLES\\n \\n................................\\n................................\\n................................\\n........\\n \\n2\\n \\n2.\\n \\nPOWER UNIT MANUFACTURER OBLIGATIONS\\n \\n................................\\n................................\\n....\\n \\n3\\n \\n3.\\n \\nEXCLUSIONS\\n \\n................................\\n................................\\n................................\\n.....................\\n \\n5\\n \\n4.\\n \\nADJUSTMENTS\\n \\n................................\\n................................\\n................................\\n..................\\n \\n8\\n \\n5.\\n \\nREPORTING R\\nEQUIREMENTS\\n \\n................................\\n................................\\n...........................\\n \\n12\\n \\n6.\\n \\nCOST CAP ADMINISTRATION\\n \\n................................\\n................................\\n...........................\\n \\n14\\n \\n7.\\n \\nCOST CAP ADJUDICATION PANEL\\n \\n................................\\n................................\\n.....................\\n \\n19\\n \\n8.\\n \\nCATEGORIES OF BREACH\\n \\n................................\\n................................\\n................................\\n.\\n \\n23\\n \\n9.\\n \\nSANCTIONS FOR BREACH\\n................................\\n................................\\n................................\\n.\\n \\n26\\n \\nAPPENDIX 1  DEFINITIONS AND INTERPRETATION\\n................................\\n................................\\n.........\\n \\n29\\n \\nAPPENDIX 2  ELIGIBLE TEST BENCHES\\n \\n................................\\n................................\\n...........................\\n \\n51\\n \\nAPPENDIX 3  TRANSITIONAL CAPITAL EXPENDITURE QUALIFYING ASSETS\\n \\n................................\\n......\\n \\n56\\n \\n \\n \\n \\n \\nFormula 1 Power Unit Financial Regulations\\n \\n2\\n \\n16 August\\n \\n2022\\n \\n\u00a9 202\\n2\\n \\n\\n \\n \\n \\nIssue \\n1\\n \\n \\n \\n1.\\n \\nGENERAL PRINCIPLES \\n \\nScope\\n \\n1.1\\n \\nThese \\nPower Unit \\nFinancial Regulations\\n \\ncome into force \\non\\n \\n1 January \\n202\\n3\\n. They form part of \\nthe terms and conditions \\nfor \\nthe \\nhomologation \\nof \\nPower Units to \\nbe supplied to\\n \\nF1 Team\\ns\\n \\nfor\\n \\nparticipation in the Championship\\n \\nfrom 2026 onwards\\n. Each \\nPower Unit Manufacturer\\n \\nintending to homologate Power Units\\n \\nfor supply \\nto an \\nF1 Team\\n(s)\\n \\nfor \\nparticipat\\nion\\n \\nin the \\nChampionship \\nfrom 2026 onwards \\nagrees to be bound by\\n,\\n \\nand \\nundertakes \\nto comply with\\n,\\n \\nthese \\nPower Unit \\nFinancial Regulations\\n \\nfrom \\nthe start of \\nits N\\n-\\n3 Full Year Reporting Period\\n.\\n \\nObjectives\\n \\n1.2\\n \\nThese \\nPower Unit \\nFinancial Regulations\\n \\nintroduce a \\nPower Unit \\nCost Cap that limits \\ncertain \\ncosts\\n \\nthat may be \\nincurred by or on behalf of \\na Power Unit Manufacturer \\nin each \\nFull Year \\nReporting Period, while leaving \\nthat \\nPower Unit Manufacturer \\nfree to decide how to allocate \\nresources within that \\nPower Unit \\nCost C\\nap. \\n \\n1.3\\n \\nThese \\nPower Unit \\nFinancial Regulations are\\n \\ndesigned to \\nhelp \\nachieve the following \\nobjectives \\n(the \\n\"\\nObjectives\\n\"\\n)\\n:\\n \\n(a)\\n \\nto promote \\nthe \\nlong\\n-\\nterm \\ncompetitive balance of the Championship\\n \\nin respect of \\nPower Units\\n;\\n \\n(b)\\n \\nto \\npromote the \\nlong\\n-\\nterm \\nsporting fairness\\n \\nof the Championship\\ ...
#   "param": null,
#   "type": "invalid_request_error"
# }

# %% [markdown]
# Como has podido observar, recibiste un mensaje de error después de ejecutar el fragmento de código anterior. El modelo alcanza su longitud de contexto máxima. Para los modelos GPT-3, el límite de tokens es de 4097 tokens. ¿Cómo solucionamos este problema al proporcionarle todo el contexto necesario, pero sin encontrarnos con el problema del límite de tokens?
#
# Para resolver este problema, podemos echar un vistazo a un concepto llamado Chunking (Segmentación).

# %% [markdown]
# ## 4. Chunking (Segmentación)
#
# La segmentación ayuda a limitar la cantidad de información que pasamos al modelo. La información que pasaremos son los trozos más relevantes de los datos en general. Hay muchas consideraciones que entran en juego al hacer segmentación. Por ejemplo, necesitas averiguar el mejor tamaño de chunk (trozo). Si los trozos son demasiado pequeños, puedes perder contexto importante. Si los trozos son demasiado grandes, pueden contener información innecesaria.
#
# A continuación se presentan algunas técnicas comunes de chunking.
#
# 1. Chunking con trozos más pequeños
# 2. Chunking dividiendo las oraciones
# 3. Chunking con superposición de oraciones
# 4. Chunking de forma recursiva
#
# Veamos estas técnicas en acción.

# %% [markdown]
# ### 4.1 Chunking con trozos más pequeños
#
# #### Tarea #4 del Estudiante:
#
# Agrega código en la celda siguiente. Utiliza la función `split()` para dividir el texto en trozos.

# %%
text = "The sun was setting over the horizon, casting a warm glow over the landscape. Birds chirped in the trees, and a gentle breeze rustled the leaves. In the distance, a herd of deer grazed in a meadow. The air was filled with the sweet scent of blooming flowers. It was a peaceful and serene scene, perfect for a quiet evening stroll."

words = text.split(' ')

print(words)
# Agrega tu código aquí
# Out:
# ['The', 'sun', 'was', 'setting', 'over', 'the', 'horizon,', 'casting', 'a', 'warm', 'glow', 'over', 'the', 'landscape.', 'Birds', 'chirped', 'in', 'the', 'trees,', 'and', 'a', 'gentle', 'breeze', 'rustled', 'the', 'leaves.', 'In', 'the', 'distance,', 'a', 'herd', 'of', 'deer', 'grazed', 'in', 'a', 'meadow.', 'The', 'air', 'was', 'filled', 'with', 'the', 'sweet', 'scent', 'of', 'blooming', 'flowers.', 'It', 'was', 'a', 'peaceful', 'and', 'serene', 'scene,', 'perfect', 'for', 'a', 'quiet', 'evening', 'stroll.']

# %% [markdown]
# ¿Qué puedes observar sobre los trozos devueltos? Si vieras cada trozo de manera individual, ¿podrías entender el significado semántico?

# %% [markdown]
# ### 4.2: Chunking dividiendo las oraciones
#
# #### Tarea #5 del Estudiante:
#
# Agrega código en la celda siguiente. Utiliza la biblioteca `spaCy` y específicamente la función `sents` para dividir el texto en trozos.

# %%
text = "Today was a fun day. I had lots of ice cream. I also met my best friend Sally and we played together at the new playground."

# Agrega tu código aquí

# Cargar el modelo de lenguaje en inglés
nlp = spacy.load("en_core_web_sm")

# Procesar el texto
doc = nlp(text)

# Dividir el texto en oraciones usando la función sents
sentences = [sent.text for sent in doc.sents]

# Imprimir las oraciones
for sentence in sentences:
    print(sentence)
# Out:
# Today was a fun day.
# I had lots of ice cream.
# I also met my best friend Sally and we played together at the new playground.

# %% [markdown]
# ¿Los resultados son mejores que el método en 4.1? La biblioteca `spaCy` ayuda a dividir el texto en oraciones individuales. Esto puede ser útil cuando intentas hacer resúmenes de texto. Puedes clasificar las oraciones individuales y usar los mejores resultados en el resumen.

# %% [markdown]
# ### 4.3: Chunking con superposición de oraciones
#
# #### Tarea #6 del Estudiante:
#
# Ejecuta el código mostrado a continuación para ver otro ejemplo de chunking. Como verás, el significado semántico se mantiene. En otras palabras, se conserva el contexto entre las oraciones. Esto es especialmente importante cuando estás buscando datos para obtener resultados relevantes o cuando estás resumiendo un fragmento de texto. Es importante capturar las relaciones entre las oraciones.

# %%
text = "The sun was setting over the horizon, casting a warm glow over the landscape. Birds chirped in the trees, and a gentle breeze rustled the leaves. In the distance, a herd of deer grazed in a meadow. The air was filled with the sweet scent of blooming flowers. It was a peaceful and serene scene, perfect for a quiet evening stroll."
doc = nlp(text)

sentences = list(doc.sents)
overlap = 1
chunks =[]

for i in range(len(sentences) - overlap):
    chunk = sentences[i : i + overlap + 1]
    chunks.append(chunk)

for chunk in chunks:
    print([sent.text for sent in chunk])
# Out:
# ['The sun was setting over the horizon, casting a warm glow over the landscape.', 'Birds chirped in the trees, and a gentle breeze rustled the leaves.']
# ['Birds chirped in the trees, and a gentle breeze rustled the leaves.', 'In the distance, a herd of deer grazed in a meadow.']
# ['In the distance, a herd of deer grazed in a meadow.', 'The air was filled with the sweet scent of blooming flowers.']
# ['The air was filled with the sweet scent of blooming flowers.', 'It was a peaceful and serene scene, perfect for a quiet evening stroll.']

# %% [markdown]
# ### 4.4: Chunking de forma recursiva usando LangChain
#
# #### Tarea #7 del Estudiante:
#
# Agrega los parámetros requeridos para `RecursiveCharacterSplitter` en la celda siguiente.

# %%
split_text = RecursiveCharacterTextSplitter(
   # Agrega los parámetros aquí
   chunk_size=100,
   chunk_overlap=20
)
docs = split_text.create_documents([clean_text])
docs
# Out:
# [Document(metadata={}, page_content='Formula 1 Power Unit Financial Regulations     1     16 August     2022     © 202  2'),
#  Document(metadata={}, page_content='202  2                Issue   1              FORMULA 1   POWER UNIT   FINANCIAL REGULATIONS'),
#  Document(metadata={}, page_content='REGULATIONS     PUBLISHED ON   16 August     2022     Issue   1        CONTENTS        Art'),
#  Document(metadata={}, page_content='Art     CONTENTS     Page(s)     1.     GENERAL PRINCIPLES'),
#  Document(metadata={}, page_content='PRINCIPLES     ................................  ................................'),
#  Document(metadata={}, page_content='................................  ........     2     2.     POWER UNIT MANUFACTURER OBLIGATIONS'),
#  Document(metadata={}, page_content='OBLIGATIONS     ................................  ................................  ....     3'),
#  Document(metadata={}, page_content='....     3     3.     EXCLUSIONS     ................................'),
#  Document(metadata={}, page_content='................................  ................................  .....................     5'),
#  Document(metadata={}, page_content='5     4.     ADJUSTMENTS     ................................  ................................'),
#  Document(metadata={}, page_content='................................  ..................     8     5.     REPORTING R  EQUIREMENTS'),
#  Document(metadata={}, page_content='R  EQUIREMENTS     ................................  ................................'),
#  Document(metadata={}, page_content='...........................     12     6.     COST CAP ADMINISTRATION'),
#  Document(metadata={}, page_content='ADMINISTRATION     ................................  ................................'),
#  Document(metadata={}, page_content='...........................     14     7.     COST CAP ADJUDICATION PANEL'),
#  Document(metadata={}, page_content='PANEL     ................................  ................................  .....................'),
#  Document(metadata={}, page_content='19     8.     CATEGORIES OF BREACH     ................................'),
#  Document(metadata={}, page_content='................................  ................................  .     23     9.     SANCTIONS'),
#  Document(metadata={}, page_content='9.     SANCTIONS FOR BREACH  ................................  ................................'),
#  Document(metadata={}, page_content='................................  .     26     APPENDIX 1 DEFINITIONS AND INTERPRETATION'),
#  Document(metadata={}, page_content='AND INTERPRETATION  ................................  ................................  .........'),
#  Document(metadata={}, page_content='.........     29     APPENDIX 2 ELIGIBLE TEST BENCHES     ................................'),
#  Document(metadata={}, page_content='................................  ...........................     51     APPENDIX 3 TRANSITIONAL'),
#  Document(metadata={}, page_content='3 TRANSITIONAL CAPITAL EXPENDITURE QUALIFYING ASSETS     ................................  ......'),
#  Document(metadata={}, page_content='......     56                 Formula 1 Power Unit Financial Regulations     2     16 August'),
#  Document(metadata={}, page_content='2     16 August     2022     © 202  2                Issue   1           1.     GENERAL PRINCIPLES'),
#  Document(metadata={}, page_content='GENERAL PRINCIPLES      Scope     1.1     These   Power Unit   Financial Regulations     come into'),
#  Document(metadata={}, page_content='come into force   on     1 January   202  3  . They form part of   the terms and conditions'),
#  Document(metadata={}, page_content='and conditions   for   the   homologation   of   Power Units to   be supplied to     F1 Team  s'),
#  Document(metadata={}, page_content='F1 Team  s     for     participation in the Championship     from 2026 onwards  . Each   Power'),
#  Document(metadata={}, page_content='. Each   Power Unit Manufacturer     intending to homologate Power Units     for supply   to an'),
#  Document(metadata={}, page_content='supply   to an   F1 Team  (s)     for   participat  ion     in the   Championship   from 2026'),
#  Document(metadata={}, page_content='from 2026 onwards   agrees to be bound by  ,     and   undertakes   to comply with  ,     these'),
#  Document(metadata={}, page_content='with  ,     these   Power Unit   Financial Regulations     from   the start of   its N  -  3 Full'),
#  Document(metadata={}, page_content='its N  -  3 Full Year Reporting Period  .     Objectives     1.2     These   Power Unit'),
#  Document(metadata={}, page_content='Power Unit   Financial Regulations     introduce a   Power Unit   Cost Cap that limits   certain'),
#  Document(metadata={}, page_content='limits   certain   costs     that may be   incurred by or on behalf of   a Power Unit Manufacturer'),
#  Document(metadata={}, page_content='Unit Manufacturer   in each   Full Year   Reporting Period, while leaving   that   Power Unit'),
#  Document(metadata={}, page_content='that   Power Unit Manufacturer   free to decide how to allocate   resources within that   Power'),
#  Document(metadata={}, page_content='within that   Power Unit   Cost C  ap.      1.3     These   Power Unit   Financial Regulations are'),
#  Document(metadata={}, page_content='Regulations are     designed to   help   achieve the following   objectives   (the   "  Objectives'),
#  Document(metadata={}, page_content='"  Objectives  "  )  :     (a)     to promote   the   long  -  term   competitive balance of the'),
#  Document(metadata={}, page_content='balance of the Championship     in respect of   Power Units        (b)     to   promote the   long'),
#  Document(metadata={}, page_content='promote the   long  -  term   sporting fairness     of the Championship     in respect of Power'),
#  Document(metadata={}, page_content='respect of Power   Units        and     (c)     to   ensure   the long  -  term financial'),
#  Document(metadata={}, page_content='term financial     stability and     sustainability of the   Power Unit   Manufacturers  ,'),
#  Document(metadata={}, page_content=',        while   preserv  ing     the     unique technolog  y and engineering challenge     of F'),
#  Document(metadata={}, page_content='challenge     of F  ormula   1  .     1.4     These   Power Unit   Financial Regulations     wi  ll'),
#  Document(metadata={}, page_content='wi  ll be interpreted and applied by the     Cost Cap   Administration  , the Cost Cap'),
#  Document(metadata={}, page_content=', the Cost Cap Adjudication Panel and the ICA   in a consistent manner that treats   all     Power'),
#  Document(metadata={}, page_content='all     Power Unit Manufacturers     equally and that   advances   the Objectives  .     1.5'),
#  Document(metadata={}, page_content='.     1.5     The definitive version of these   Power Unit   Financial Regulations     is the'),
#  Document(metadata={}, page_content='is the English version, which   will be used should any dispute arise as to their'),
#  Document(metadata={}, page_content='arise as to their interpretation. Defined w  ords and phrases in   these   Power Unit   Financ  ial'),
#  Document(metadata={}, page_content='Unit   Financ  ial Regulations     (denoted by initial capital letters) have the meaning'),
#  Document(metadata={}, page_content='have the meaning   indicated     in     Appendix   1   to these   Power Unit   Financial'),
#  Document(metadata={}, page_content='Unit   Financial Regulations  , unless otherwise defined   in the body of these   Power Unit'),
#  Document(metadata={}, page_content='Power Unit   Financial Regulations  .     Unless otherwise specified, references   to   "'),
#  Document(metadata={}, page_content='to   "  Articles  "     are to Articles     of these   Power Unit   Financial Regulations  ,'),
#  Document(metadata={}, page_content='Regulations  ,     references to "may"   shall mean in the sole discretion of such person or entity'),
#  Document(metadata={}, page_content='person or entity (as the context so requires),   and any   phrase introduced by the t  erms'),
#  Document(metadata={}, page_content='by the t  erms "including", "include", "in particular" or any similar expression   shall be'),
#  Document(metadata={}, page_content='shall be construed as illustrative and not   as   limit  ing     the sense of the words preceding'),
#  Document(metadata={}, page_content='the words preceding those   terms.        1.6     If any part of these   Power Unit   Financial'),
#  Document(metadata={}, page_content='Unit   Financial Regulations     is found by a court or authority of   competent jurisdiction to be'),
#  Document(metadata={}, page_content='jurisdiction to be illegal, invalid or unenforceable, that part will be deemed not to   form part'),
#  Document(metadata={}, page_content='not to   form part of these   Power Unit   Financial Regulations  , and the legality, validity or'),
#  Document(metadata={}, page_content='validity or enforceability   of the remainder of these     Power Unit   Financial Regulations'),
#  Document(metadata={}, page_content='Regulations     will not be affected.        Formula 1 Power Unit Financial Regulations     3'),
#  Document(metadata={}, page_content='3     16 August     2022     © 202  2                Issue   1           1.7     The Cost Cap'),
#  Document(metadata={}, page_content='The Cost Cap   Administration     shall periodically review these   Power Unit   Financial'),
#  Document(metadata={}, page_content='Unit   Financial Regulations  .   The  se   Power Unit   Financial Regulations     may be amen  ded'),
#  Document(metadata={}, page_content='may be amen  ded and/or supplemented by the FIA   World   Motor     S  port Cou  ncil from time'),
#  Document(metadata={}, page_content='Cou  ncil from time to time  .     Accountability      1.8     Each   Power Unit Manufacturer'),
#  Document(metadata={}, page_content='Unit Manufacturer   must   ensure that all Personnel are made   aware:     (a)     of the'),
#  Document(metadata={}, page_content='(a)     of the Objectives, content and substance of these   Power Unit   Financial Regulations'),
#  Document(metadata={}, page_content='Regulations        and     (  b  )         that the   Power Unit Manufacturer     is subject to'),
#  Document(metadata={}, page_content='is subject to these   Power Unit   Financial Regulations.     1.9     E  ach   Power Unit'),
#  Document(metadata={}, page_content='E  ach   Power Unit Manufacturer     must   ensure that   all relevant   Personnel are'),
#  Document(metadata={}, page_content='Personnel are appropriately   informed and trained with respect to the ways in which their areas'),
#  Document(metadata={}, page_content='which their areas of responsibility may   impact the   Power Unit Man  ufacturer    se     Power'),
#  Document(metadata={}, page_content='se     Power   Unit   Financial   Regulations.      1.10     E  ach   Power Unit Manufacturer'),
#  Document(metadata={}, page_content='Manufacturer     must   ensure that   the FIA     ethics and compliance   policy in force   from'),
#  Document(metadata={}, page_content='in force   from time to time with respect to these   Power Unit   Financial Regulations is clearly'),
#  Document(metadata={}, page_content='is clearly   communicated to all Personnel.     2.     POWER UNIT MANUFACTURER     OBLIGATIONS'),
#  Document(metadata={}, page_content='OBLIGATIONS     2.1     Each   Power Unit Manufacturer     must  :     (a)     demonstrate its'),
#  Document(metadata={}, page_content='demonstrate its ongoing compliance with the   Power Unit   Cost Cap by submitting   Reporting'),
#  Document(metadata={}, page_content='Reporting Documentation in respect of its Reporting Group to the Cost Cap   Ad  ministration'),
#  Document(metadata={}, page_content='ministration     by the Reporting Deadline in   respect of   each Reporting Period and by'),
#  Document(metadata={}, page_content='Period and by   providing any further information requested from time to time by the Cost Cap'),
#  Document(metadata={}, page_content='by the Cost Cap   Administration         (b)     cooperate fully and   in a timely manner   with'),
#  Document(metadata={}, page_content='manner   with     the Cost Cap Administration in     the   exercise of   its     regulatory'),
#  Document(metadata={}, page_content='its     regulatory function, including   any investigation conducted by or on   behalf of the Cost'),
#  Document(metadata={}, page_content='behalf of the Cost Cap   Administration     pursuant to     these   Power Unit   Financial'),
#  Document(metadata={}, page_content='Unit   Financial   Regulations     and/or with the Financial Regulations           (c)     provide'),
#  Document(metadata={}, page_content='(c)     provide any information     and documentation     requested by or on behalf of the Cost'),
#  Document(metadata={}, page_content='behalf of the Cost   Cap Administration   relevant to any actual  ,     potential     or'),
#  Document(metadata={}, page_content='potential     or   suspected     instance of non  -  compliance with these   Power Unit'),
#  Document(metadata={}, page_content='Power Unit   Financial Regulations     and/or with the Financial   Regulations    and     (d)'),
#  Document(metadata={}, page_content='and     (d)     faithfully execute its obligations und  er these   Power Unit   Financial'),
#  Document(metadata={}, page_content='Unit   Financial Regulations     and act     at all times     in     a spirit of     G  ood   F'),
#  Document(metadata={}, page_content='of     G  ood   F  aith and   cooperation  .        Cap     on Relevant Costs     2.2     A'),
#  Document(metadata={}, page_content='2.2     A     Power Unit Manufacturer   must  :     (a)     determine and report     its'),
#  Document(metadata={}, page_content='and report     its Relevant Costs against the   Power Unit   Cost Cap in the   Power   Unit'),
#  Document(metadata={}, page_content='Power   Unit   Manufacturer      and        Formula 1 Power Unit Financial Regulations     4'),
#  Document(metadata={}, page_content='4     16 August     2022     © 202  2                Issue   1           (b)     not   have'),
#  Document(metadata={}, page_content='not   have     Relevant Costs   in excess of the   Power Unit   Cost Cap   in   the applicable'),
#  Document(metadata={}, page_content='the applicable     Full   Year   Reporting Period  .     The   Power Unit   Cost Cap     2.3'),
#  Document(metadata={}, page_content='Cap     2.3     The amount of the "  Power Unit     Cost Cap  " shall be     as follows  :     (a)'),
#  Document(metadata={}, page_content='follows  :     (a)     in the Full Year   Reporting Period  s     ending on 31 December 202  3, 31'),
#  Document(metadata={}, page_content='December 202  3, 31 December 2024   and 31 December 2025  , US Dollars 95,000,000  , adjusted for'),
#  Document(metadata={}, page_content=', adjusted for Indexation        and     (b)     in the Full Year Reporting Period ending on 31'),
#  Document(metadata={}, page_content='Period ending on 31 December 202  6     and in each subsequent   Full Year Reporting Period  , US'),
#  Document(metadata={}, page_content='Period  , US Doll  ars 130,000,000  , adjusted for Indexation  .     2.4     Where a   Power Unit'),
#  Document(metadata={}, page_content='a   Power Unit Manufacturer   has a Presentation Currency other than US Dollars, the   Power Unit'),
#  Document(metadata={}, page_content='the   Power Unit   Cost Cap for that   Power Unit Manufacturer     shall be converted from US'),
#  Document(metadata={}, page_content='converted from US Dollars   into   that   Power Unit Manufacturer       Presentation Currency at'),
#  Document(metadata={}, page_content='Currency at the Initial Applicable Rate. For   illustrative purposes, the amount of the   Power'),
#  Document(metadata={}, page_content='of the   Power Unit   Cost Cap in selected Presentation   Currencies for the Full Year Reporting'),
#  Document(metadata={}, page_content='Full Year Reporting Period   ending on 31 December 202  3  , as   referred to in   Article   2.3'),
#  Document(metadata={}, page_content='in   Article   2.3  (a)   (as  suming Indexation of zero)   is     as follows:     US Dollars'),
#  Document(metadata={}, page_content='US Dollars           Pounds Sterling           Euros           95,000     76,459     90,210'),
#  Document(metadata={}, page_content='90,210        Reporting Group     2.5     F  or   the   purposes of   reporting   Total'),
#  Document(metadata={}, page_content='Total     Costs     of the Reporting Group  ,     a     Power Unit   Manufacturer       Reporting'),
#  Document(metadata={}, page_content='Reporting Group     shall   comprise the   Power Unit Manufacturer     together with  ,'),
#  Document(metadata={}, page_content='together with  ,   where the   Power Unit Manufacturer     has incurred less than 95% of the costs'),
#  Document(metadata={}, page_content='95% of the costs of the   Power Unit   Activities undertaken by or on behalf of the   Power Unit'),
#  Document(metadata={}, page_content='of the   Power Unit Manufacturer     in the Reporting Period,     such   additional   en  tities'),
#  Document(metadata={}, page_content="en  tities within the   Power Unit Manufacturer  's Legal G  ro  up S  tructure     as are"),
#  Document(metadata={}, page_content='as are   determined in accordance with     Article   2.6  .     2.6     The   additional'),
#  Document(metadata={}, page_content='The   additional   entities to be included within   the     Reporting Group   where   a     Power'),
#  Document(metadata={}, page_content='where   a     Power Unit   Manufacturer     has incurred less than 95% of the costs of the   Power'),
#  Document(metadata={}, page_content='of the   Power Unit   Activities undertaken   by or on behalf of   that   Power Unit Manufacturer'),
#  Document(metadata={}, page_content='Unit Manufacturer     in the Reporting Period   shall be     the entity   (other than the   Power'),
#  Document(metadata={}, page_content='than the   Power Unit Manufacturer  ) within the   Power Unit Manufacturer    Structure that'),
#  Document(metadata={}, page_content='Structure that incurred the greatest amount of costs     of the   Power Unit   Activities'),
#  Document(metadata={}, page_content='Unit   Activities undertaken   by or on behalf of the   Power Unit Manufacturer     in the'),
#  Document(metadata={}, page_content='in the Reporting Period  , followed   (to the   extent required)   by   the entity     within'),
#  Document(metadata={}, page_content='entity     within the   Power Unit Manufacturer    that incurred     the next greatest amou  nt of'),
#  Document(metadata={}, page_content='amou  nt of   such   costs, and so on, until   the entities included   within   the     Reporting'),
#  Document(metadata={}, page_content='the     Reporting Group have     incurred  ,     in aggregate, 95%   or more   of the costs of'),
#  Document(metadata={}, page_content='of the costs of the   Power   Unit   Activities undertaken by or on behalf of the   Power Unit'),
#  Document(metadata={}, page_content='of the   Power Unit Manufacturer     in the Reporting   Period.      2.7     I  n addition to those'),
#  Document(metadata={}, page_content='n addition to those   entities   included     in the Reporting Group   pursuant to Article  s'),
#  Document(metadata={}, page_content='to Article  s     2.5     and   2.6  ,   a     Power Unit Manufacturer     may elect to include'),
#  Document(metadata={}, page_content='elect to include additional entities in its Reporting Group      Formula 1 Power Unit Financial'),
#  Document(metadata={}, page_content='Unit Financial Regulations     5     16 August     2022     © 202  2                Issue   1'),
#  Document(metadata={}, page_content='Issue   1           from     w  ithin its Legal Group Structure     which have incurred costs'),
#  Document(metadata={}, page_content='have incurred costs of   Power Unit   Activities   undertaken on behalf of the   Power Unit'),
#  Document(metadata={}, page_content='of the   Power Unit Manufacturer     in the Reporting Period  .     2.8     For the purposes of'),
#  Document(metadata={}, page_content='For the purposes of Articles     2.5     to     2.7     (inclusive)  ,     t  he calculation of the'),
#  Document(metadata={}, page_content='calculation of the costs of   Power Unit   Activities undertaken by or on behalf of the   Power'),
#  Document(metadata={}, page_content='of the   Power Unit Manufacturer     in the Reporting Period:     (a)     shall not include'),
#  Document(metadata={}, page_content='shall not include   Finance Costs and   costs Directly Attributable to Marketing   Activities'),
#  Document(metadata={}, page_content='Activities        (b)     shall be made having adjusted   out     any amounts in connection with'),
#  Document(metadata={}, page_content='in connection with   Power Unit   Activities recharged from one member of the   Power Unit'),
#  Document(metadata={}, page_content='of the   Power Unit Manufacturer    egal Group   Structure to another  .     2.9     I  n th  e'),
#  Document(metadata={}, page_content='I  n th  e     calculation of Relevant Costs, the costs of any   Power Unit   Activities'),
#  Document(metadata={}, page_content="Unit   Activities   incurred by     entities   within the   Power Unit Manufacturer  's Legal Group"),
#  Document(metadata={}, page_content="'s Legal Group Structure but outside its Reporting Group  ,   other than   Finance Costs and"),
#  Document(metadata={}, page_content='Finance Costs and   costs Directly Attributable to   Marketing   Activities undertaken   by any'),
#  Document(metadata={}, page_content='undertaken   by any such entity,     must either be:     (a)     recharged a  t Fair Value to a'),
#  Document(metadata={}, page_content='Fair Value to a     Reporting Group     Entity and thereby included within Total   Costs     of the'),
#  Document(metadata={}, page_content='Costs     of the Reporting Group    or      (b)     included   in Relevant Costs   at Fair Value'),
#  Document(metadata={}, page_content='at Fair Value by   way of an Adjustment to Total     Cost  s     of the   Reporting Group  , as a'),
#  Document(metadata={}, page_content='Group  , as a Related Party Transaction pursuant to Article 4.1(a)(i)  .     2.10     The   Power'),
#  Document(metadata={}, page_content='The   Power Unit Manufacturer     should seek clarification from the Cost Cap Administration if'),
#  Document(metadata={}, page_content='Administration if it   is uncertain whether an entity should be included in its Reporting Group.'),
#  Document(metadata={}, page_content='Reporting Group.     3.     E  XCLUSIONS     3.1     In calculating     Relevant Costs  ,     t  he'),
#  Document(metadata={}, page_content='Costs  ,     t  he following   costs and   amounts     within Total Costs     of the   Reporting'),
#  Document(metadata={}, page_content='of the   Reporting Group   must     be excluded     (  "  Excluded Costs  "  )  :     (a)     A'),
#  Document(metadata={}, page_content=')  :     (a)     A  ll costs   D  irectly   A  ttributable to Marketing Activities        (b)'),
#  Document(metadata={}, page_content='(b)     With respect to Heritage Asset Activities:     (i)     a  ll costs   D  irectly   A'),
#  Document(metadata={}, page_content='D  irectly   A  ttributable to Heritage Asset Activities        and     (ii)     if the Power'),
#  Document(metadata={}, page_content='if the Power Unit Manufacturer can prove to the satisfaction of   the   Cost Cap'),
#  Document(metadata={}, page_content='the   Cost Cap   Administration that an identifiable portion of the Consideration provided to'),
#  Document(metadata={}, page_content='provided to   any Heritage Asset Personnel relates   to Heritage Asset Activities, that portion'),
#  Document(metadata={}, page_content='that portion     contributions      (c)     All   Finance     Costs        (d)     A  ll'),
#  Document(metadata={}, page_content='(d)     A  ll   Corporate Income Tax        (e)     With respect to Non  -  Power Unit'),
#  Document(metadata={}, page_content='-  Power Unit   Activities:      (i)     a  ll costs   D  irectly   A  ttributable to   Non  -'),
#  Document(metadata={}, page_content='to   Non  -  Power Unit   Activities    and        Formula 1 Power Unit Financial Regulations     6'),
#  Document(metadata={}, page_content='Regulations     6     16 August     2022     © 202  2                Issue   1           (ii)'),
#  Document(metadata={}, page_content='(ii)     if     the   Power Unit Manufacturer     can prove to the satisfaction of the'),
#  Document(metadata={}, page_content='satisfaction of the Cost Cap   Administration     that an identifiable portion of     the following'),
#  Document(metadata={}, page_content='the following costs     relates to     Non  -  Power Unit   Activities  , that portion of those'),
#  Document(metadata={}, page_content='portion of those costs  :     (A)     Consideration   provided to  ,       contributions incurred'),
#  Document(metadata={}, page_content='incurred in respect of  ,     an  y Personnel     engaged in     both     Power Unit   Activities'),
#  Document(metadata={}, page_content='Unit   Activities     and   Non  -  Power Unit   Activities        (B)     e  lectricity, gas   and'),
#  Document(metadata={}, page_content='gas   and   water     costs     incurred     in the cours  e of both   Power   Unit   Activities'),
#  Document(metadata={}, page_content='Unit   Activities and Non  -  Power Unit   Activities         (C)     lease costs in respect of'),
#  Document(metadata={}, page_content='costs in respect of plant and equipment     used in the cours  e of   both   Power Unit'),
#  Document(metadata={}, page_content='both   Power Unit   Activities and Non  -  Power Unit   Activities        and     (D)     costs of'),
#  Document(metadata={}, page_content='(D)     costs of   parts and consumables  ,     and   outsourced     service  s  ,     incurred'),
#  Document(metadata={}, page_content='s  ,     incurred for   the     maintenance of   an item of   plant or equipment used in the'),
#  Document(metadata={}, page_content='used in the course   of both   Power Unit   Activities and Non  -  Power Unit   Activities      (f)'),
#  Document(metadata={}, page_content='Activities      (f)     All costs   D  irectly   A  ttributab  le to Human Resources Activit  ies'),
#  Document(metadata={}, page_content='Activit  ies  ,     Finance Act  ivit  ies     or     Legal Activit  ies        (g)     All'),
#  Document(metadata={}, page_content='(g)     All Property   Cost  s        (h)     All   Employee     Bonus Costs  , subject to a'),
#  Document(metadata={}, page_content=', subject to a maximum   amount     in any Full Year Reporting   Period   of     the lower of  :'),
#  Document(metadata={}, page_content='the lower of  :        (i)       20  % of the   Total   Fixed   Employee     Remuneration'),
#  Document(metadata={}, page_content='Remuneration        and           (ii)     US Dollars 7,500,000  , adjusted for Indexation'),
#  Document(metadata={}, page_content='Indexation           plus the amount of any     amount of such Employee Bonus Costs excluded'),
#  Document(metadata={}, page_content='Costs excluded pursuant to this Article   3.1(h)              (i)     All registration   and'),
#  Document(metadata={}, page_content='registration   and administration   fees     payable to the FIA by a     Power Unit   Manufacturer'),
#  Document(metadata={}, page_content='Manufacturer     in relation to   the registration and homologation of   its   Power Units in'),
#  Document(metadata={}, page_content='Power Units in   respect of     the Championship taking place in the applicable Reporting Period'),
#  Document(metadata={}, page_content='Reporting Period      (j)     All   F  in  ancial Penalties     in respect of any breach of   these'),
#  Document(metadata={}, page_content='breach of   these   Power Unit   Financial   Regulations        (k)     All amounts of'),
#  Document(metadata={}, page_content='All amounts of depreciation,   amortisation, impairment loss  ,     and amounts as a result'),
#  Document(metadata={}, page_content='as a result   of revaluation or disposal of tangible assets and intangible assets        (l)'),
#  Document(metadata={}, page_content='(l)     All foreign exchange gains and losses     recognised in profit or loss  , whether'),
#  Document(metadata={}, page_content='or loss  , whether arising from   settlement and/or re  -  measurement of monetar  y items'),
#  Document(metadata={}, page_content='of monetar  y items denominated in a foreign   currency, or otherwise        (m)     Where a'),
#  Document(metadata={}, page_content='(m)     Where a Reporting Group Entity is required     by   applicable   law  s     to pay'),
#  Document(metadata={}, page_content='law  s     to pay employer       social   security   contributions  , the amount by which such'),
#  Document(metadata={}, page_content='by which such mandatory contributions exceed   13.8  % of the Total Employee   Remuneration'),
#  Document(metadata={}, page_content='Formula 1 Power Unit Financial Regulations     7     16 August     2022     © 202  2'),
#  Document(metadata={}, page_content='© 202  2                Issue   1           (n)     All   Health   A  nd   S  afety     Costs'),
#  Document(metadata={}, page_content='afety     Costs        (o)     With respect to Customer Team Power Unit Activities:     (i)'),
#  Document(metadata={}, page_content='(i)     All costs Directly Attributable to Customer Team Power Unit Activities  and     (ii)'),
#  Document(metadata={}, page_content='and     (ii)     If a Power Unit Manufacturer can prove to the satisfaction of the Cost Cap'),
#  Document(metadata={}, page_content='of the Cost Cap   Administration that an identifiable portion of the following costs relates to'),
#  Document(metadata={}, page_content='costs relates to   Customer Team Power Unit Activities, that portion of those costs:     (A)'),
#  Document(metadata={}, page_content='(A)       contributions incurred in respect of  ,     any P  ersonnel engaged in Power   Unit'),
#  Document(metadata={}, page_content='in Power   Unit Activities      (B)     e  lectricity, gas and water costs incurred in the course'),
#  Document(metadata={}, page_content='in the course of Power Unit   Activities      (C)     lease costs in respect of plant and equipment'),
#  Document(metadata={}, page_content='plant and equipment used in the course of   Power Unit Activities  and     (D)     costs of parts'),
#  Document(metadata={}, page_content='costs of parts and consumables, and   outsourced services, incurred for   the maintenance of an'),
#  Document(metadata={}, page_content='maintenance of an item of plant or equipment used in the course   of Power Unit Activities      (p)'),
#  Document(metadata={}, page_content='Activities      (p)     With respect to Current Generation Power Unit Activities     and   in'),
#  Document(metadata={}, page_content='and   in respect of the Full   Year Reporting Periods ending on 31 December     2023, 31'),
#  Document(metadata={}, page_content='2023, 31 December 2024 and 31   December 2025     only  :     (i)     All costs Directly'),
#  Document(metadata={}, page_content='All costs Directly Attributable to Current Generation Power Unit Activities  and     (ii)     If'),
#  Document(metadata={}, page_content='(ii)     If   a     Power Unit Manufacturer can prove to the satisfaction of the Cost Cap'),
#  Document(metadata={}, page_content='of the Cost Cap   Administration that an identifiable portion of the following costs relates to'),
#  Document(metadata={}, page_content='costs relates to   Current Generation   Power Unit Activities, that portion of those     costs:'),
#  Document(metadata={}, page_content='costs:     (A)     Consideration provided to, and assoc    curity   contributions incurred in'),
#  Document(metadata={}, page_content='incurred in respect of  ,     any Personnel engaged in     Power   Unit Activities      (B)     e'),
#  Document(metadata={}, page_content='(B)     e  lectricity, gas and water costs incurred in the course of Power Unit   Activities'),
#  Document(metadata={}, page_content='Unit   Activities      (C)     lease costs in respect of plant and equipment used in t  he course'),
#  Document(metadata={}, page_content='in t  he course of   Power Unit Activities  and     (D)     costs of parts and consumables, and'),
#  Document(metadata={}, page_content='consumables, and outsourced services, incurred for   the maintenance of an item of plant or'),
#  Document(metadata={}, page_content='an item of plant or equipment used in the course   of Power Unit Activities        (q)     A  ll'),
#  Document(metadata={}, page_content='(q)     A  ll   Employee     Termination Benefits     (together with   associated employer'),
#  Document(metadata={}, page_content='employer    security contributions  )  , incurred in the Full Year Reporting Periods ending on 31'),
#  Document(metadata={}, page_content='ending on 31   December   2023  , 31 December 2024     and 31 December   2025    and        Formula'),
#  Document(metadata={}, page_content='and        Formula 1 Power Unit Financial Regulations     8     16 August     2022     © 202  2'),
#  Document(metadata={}, page_content='© 202  2                Issue   1           (r)     All costs of Consideration other than'),
#  Document(metadata={}, page_content='other than Employee Termination Benefits (together with   asso    Employee prior to the date on'),
#  Document(metadata={}, page_content='to the date on which they became a Reassigned Employee, subject to   a maximum aggregate amount of'),
#  Document(metadata={}, page_content='aggregate amount of US Dollars 3,000,000  , adjusted for Indexation  .        3.2     If a cost'),
#  Document(metadata={}, page_content='3.2     If a cost within Total     Costs of the Reporting Group is   Directly Attributable to any'),
#  Document(metadata={}, page_content='Attributable to any combination   of the following activities  :     (a)     Marketing Activities'),
#  Document(metadata={}, page_content='Activities       (b)     Heritage Asset Activities       (c)     Non  -  Power Unit   Activities'),
#  Document(metadata={}, page_content='Activities       (d)     Human Resource  s     Activities       (e)     Finance Activities'),
#  Document(metadata={}, page_content='Activities      (f)     Legal Activities        (g)     C  ustomer   T  eam   Power Unit Activities'),
#  Document(metadata={}, page_content='Unit Activities    and     (h)     C  urrent   G  eneration P  ower Unit Activities  ,      such'),
#  Document(metadata={}, page_content=',      such cost shall be an Excluded Cost.      3.3     For the purposes of this Article 3, where'),
#  Document(metadata={}, page_content='Article 3, where a     Power Unit Manufacturer     has a Presentation   Currency other than US'),
#  Document(metadata={}, page_content='other than US Dollars  ,     amount  s     expresse  d in US Dollars shall be converted into that'),
#  Document(metadata={}, page_content='into that   Power Unit Manufacturer       4.     ADJUSTMENTS     4.1     Unless stated otherwise in'),
#  Document(metadata={}, page_content='stated otherwise in this Article   4  , i  n calculating Relevant Costs, the following   a'),
#  Document(metadata={}, page_content='the following   a  djustments   to Total Costs   of the Reporting Group   must   be made:     (a)'),
#  Document(metadata={}, page_content='be made:     (a)     Related Party Transactions, Exchange Transactions     and   F1   Team'),
#  Document(metadata={}, page_content='and   F1   Team Transactions:     A  ny   Related Party Transaction  , Exchange Transaction'),
#  Document(metadata={}, page_content='Transaction     or F1   Team Transaction     in   connection with   a     Power Unit   Activity'),
#  Document(metadata={}, page_content='Unit   Activity     must be   includ  ed in Relevant Costs   at     not     less   than   Fair'),
#  Document(metadata={}, page_content='less   than   Fair Value.        (b)     Offsetting of   i  ncome and   c  osts  :     If   a'),
#  Document(metadata={}, page_content='osts  :     If   a Reporting Group   Entity   has offset   any   income or   gains     within'),
#  Document(metadata={}, page_content='gains     within   its     Total     Costs,   or any   costs or losses     within   its   revenue,'),
#  Document(metadata={}, page_content='its   revenue,     the   Power Unit Manufacturer     must make an   upward   adjustment     in'),
#  Document(metadata={}, page_content='in     the     calculation of     Relevant Costs to gross up   these     amounts, unless  :'),
#  Document(metadata={}, page_content='unless  :     (i)     such offsetting is permitted under   its     applicable accounting standards'),
#  Document(metadata={}, page_content='standards  ,   with   the exception of     any   income from a government incentive scheme   in'),
#  Document(metadata={}, page_content='scheme   in respect   of certain research and development costs included within Total Costs'),
#  Document(metadata={}, page_content='Total Costs     that   has been offset against such costs     in which case   the Power Unit'),
#  Document(metadata={}, page_content='the Power Unit   Manufacturer      Formula 1 Power Unit Financial Regulations     9     16 August'),
#  Document(metadata={}, page_content='9     16 August     2022     © 202  2                Issue   1           must make an upward'),
#  Document(metadata={}, page_content='must make an upward adjustment in the calculation of Relevant Costs to gross   up these amounts'),
#  Document(metadata={}, page_content='these amounts        or      (ii)     f  inance income   ha  s     be  en     offset against'),
#  Document(metadata={}, page_content='offset against Finance Costs, provided   that any   exclusion made pursuant to Article   3.1(c)'),
#  Document(metadata={}, page_content='to Article   3.1(c)     is made net of finance income    or     (iii)     t  ax credits in respect'),
#  Document(metadata={}, page_content='credits in respect of   C  orporate   Income T  ax   have     be  e  n     offset against tax'),
#  Document(metadata={}, page_content='against tax   charges in respect   of   C  orporate   Income T  ax, provided   that any exclusion'),
#  Document(metadata={}, page_content='that any exclusion made   purs  uant to Article   3.1(d)     is made net of tax credits     in'),
#  Document(metadata={}, page_content='tax credits     in respect of Corporate   Income Tax  .     (c)     Research and Development   c'),
#  Document(metadata={}, page_content='Development   c  osts  :        (i)     All costs     in respect of     Research and Development'),
#  Document(metadata={}, page_content='and Development   for     Power Unit   Activities     must be included in Relevant Costs   in'),
#  Document(metadata={}, page_content='Costs   in     the Reporting Period in which they are   incurred.     (ii)     If     a Reporting'),
#  Document(metadata={}, page_content='If     a Reporting Group Entity   has   defer  red     recognition of   any costs   in respect of'),
#  Document(metadata={}, page_content='in respect of     Research and Development   for   Power Unit   Activities   to   a'),
#  Document(metadata={}, page_content='to   a     subsequent   Reporting Period,   an adjustment     must be made   in     the'),
#  Document(metadata={}, page_content='made   in     the calculation of Relevant   Costs   to ensure such costs are   recognised   with'),
#  Document(metadata={}, page_content='recognised   with  in   the Reporting Period in which   they are incurred  .        (d)'),
#  Document(metadata={}, page_content='.        (d)     Capitalisation of   Power Units  :     If a Reporting Group Entity has'),
#  Document(metadata={}, page_content='Group Entity has capitalised any costs   in respect   of   a Power Unit     during   the Reporting'),
#  Document(metadata={}, page_content='the Reporting Period, an adjustment must be made in the calculation of Relevant Costs   to ensure'),
#  Document(metadata={}, page_content='Costs   to ensure such costs are recognised within the Reporting Period in which they are'),
#  Document(metadata={}, page_content='in which they are   incurred.     (e)     Capital Expenditure  :     (i)     The amount (if any) by'),
#  Document(metadata={}, page_content='amount (if any) by which   the Capital Expenditure Amount     for     the Full Year   Reporting'),
#  Document(metadata={}, page_content='Year   Reporting Period exceeds the Capital Expenditure   Limit     must be included in   the'),
#  Document(metadata={}, page_content='included in   the calculation of Relevant Costs  .     (ii)     If the costs incurred as part of a'),
#  Document(metadata={}, page_content='as part of a Related Party Transaction, Exchange   Transaction or   F1 Team     Transaction meet'),
#  Document(metadata={}, page_content='Transaction meet the definition of paragraphs (a) or   (b) of the definition of Capital'),
#  Document(metadata={}, page_content='of Capital Expenditure, such costs must be included in   Capital Expenditure at not less   than'),
#  Document(metadata={}, page_content='at not less   than Fair Value.     (f)     Inventories  :     (i)     I  f the accounting treatment'),
#  Document(metadata={}, page_content='treatment of   I  nventories     within Total Costs   of the Reporting   Group   varies from the'),
#  Document(metadata={}, page_content='varies from the   following   requirements  , the   Power Unit Manufacturer     must make an   a'),
#  Document(metadata={}, page_content='must make an   a  djustment in the calculation of Relevant Costs     to reflect   these'),
#  Document(metadata={}, page_content='reflect   these   requirements  :     (A)     the cost of an item of Used Inventories must be'),
#  Document(metadata={}, page_content='Inventories must be recognised in full as   an expense in   the Full Year Reporting Period   in'),
#  Document(metadata={}, page_content='Period   in which it was first used   in respect of the     , provided      Formula 1 Power Unit'),
#  Document(metadata={}, page_content='1 Power Unit Financial Regulations     10     16 August     2022     © 202  2                Issue'),
#  Document(metadata={}, page_content='Issue   1           that where such use occurs p  rior to 1 January   of its N  -  3'),
#  Document(metadata={}, page_content='of its N  -  3 Full Year   Reporting Period and the item is re  -  used during the N  -  3 Full'),
#  Document(metadata={}, page_content='the N  -  3 Full Year   Reporting Period  , the cost of that item of Used Inventories must be'),
#  Document(metadata={}, page_content='must be   recognised in full as an expense     in the   N  -  3   Full Year Reporting Period'),
#  Document(metadata={}, page_content='Period        (B)     the cost of     an item of Unused Inventories must not be recognised in   the'),
#  Document(metadata={}, page_content='recognised in   the Reporting Period  and     (C)     the cost of   an item of   Redundant'),
#  Document(metadata={}, page_content='item of   Redundant Inventories   (which has not been   recognised in a previous Full Year'),
#  Document(metadata={}, page_content='previous Full Year Reporting Period pursuant to any   other provision of this Article 4.1(f)(i  ))'),
#  Document(metadata={}, page_content='4.1(f)(i  ))   must be recognised in full as an   expense in the Reporting Period.   W  here'),
#  Document(metadata={}, page_content='Period.   W  here practicable, the identification   of Redundant Inventories must be carried out on'),
#  Document(metadata={}, page_content='be carried out on an item  -  by  -  item   basis. Otherwise, groups of similar items may be'),
#  Document(metadata={}, page_content='items may be considered   together  .        (ii)     T  he cost of   an item of   I  nventories'),
#  Document(metadata={}, page_content='of   I  nventories must comprise  :        (A)     all costs of purchase  ,   determined     on the'),
#  Document(metadata={}, page_content='on the same basis as that used by   the   Power Unit Manufacturer     in its Audited Annual'),
#  Document(metadata={}, page_content='its Audited Annual Financial   Statements     in respect of the previous Full Year Reporting Period'),
#  Document(metadata={}, page_content='Reporting Period           (B)     costs of conversion     (  including fixed production overheads'),
#  Document(metadata={}, page_content='overheads allocated on   a basis that is appropriate to the nature of the product and method of'),
#  Document(metadata={}, page_content="and method of   production and on the basis of the entity's normal level of activity, and   applied"),
#  Document(metadata={}, page_content='and   applied consistently from o  ne   R  eporting   P  eriod to another)      a  nd      (C)'),
#  Document(metadata={}, page_content='a  nd      (C)     other costs incurred in bringing the   item of   I  nventories to   its'),
#  Document(metadata={}, page_content='to   its   present   location and condition  .     (iii)        In the event that an item of'),
#  Document(metadata={}, page_content='that an item of Redundant Inventories:     (A)     has     not been used    and     (B)     is not'),
#  Document(metadata={}, page_content='(B)     is not     of     a technical specification that is     specific to the Power Units'),
#  Document(metadata={}, page_content='the Power Units   supplied to either the Nominated Team or any     one     Customer Team     of'),
#  Document(metadata={}, page_content='Team     of   the Power Unit Manufacturer    and     (C)     its cost   has     been   recognised'),
#  Document(metadata={}, page_content='been   recognised in full as an expense     in the Reporting   Period pursuant to paragraph'),
#  Document(metadata={}, page_content='to paragraph (i)(C) of this Article  ,     the agg  regate cost of all such items   must be'),
#  Document(metadata={}, page_content='items   must be allocated on a  n equal     pro  -  rata   basis across the Nominated Team and'),
#  Document(metadata={}, page_content='Team and   each     Customer Team of the Power Unit   Manufacturer. The Power Unit Manufacturer'),
#  Document(metadata={}, page_content='Unit Manufacturer must then make a downward   adjustment in the calculation of Relevant Cost  s for'),
#  Document(metadata={}, page_content='Cost  s for the Reporting Period equal   to the   aggregate   amount allocated to the Customer'),
#  Document(metadata={}, page_content='to the Customer     Teams.     (iv)     In the event   that   an item of   Redundant Inventories'),
#  Document(metadata={}, page_content='Inventories     written off in a previous   Reporting Period pursuant to paragraph   (i)(  C  )'),
#  Document(metadata={}, page_content='(i)(  C  )     of this Article is used in a   subsequent Reporting Period, the   Power Unit'),
#  Document(metadata={}, page_content='the   Power Unit Manufacturer     must make an   adjustment in the calculation of Relevant Costs'),
#  Document(metadata={}, page_content='of Relevant Costs for that subsequent Reporting      Formula 1 Power Unit Financial Regulations'),
#  Document(metadata={}, page_content='Regulations     11     16 August     2022     © 202  2                Issue   1           Period to'),
#  Document(metadata={}, page_content='Period to add an amount equal to that written off in the previous Reporting   Pe  riod.'),
#  Document(metadata={}, page_content='Pe  riod.        (g)     Unrecorded costs or losses:     If     costs or     losses   incurred by'),
#  Document(metadata={}, page_content='incurred by a Reporting Group Entity are not   recognised     within its   Total Costs,   which'),
#  Document(metadata={}, page_content='Costs,   which under the applicable accounting standards should have been   recognised within'),
#  Document(metadata={}, page_content='recognised within profit or loss     during the Reporting Per  iod  ,   an adjustment must be'),
#  Document(metadata={}, page_content='must be   made in the calculation of Relevant Costs to ensure such costs are recognised     within'),
#  Document(metadata={}, page_content='within     Relevant Costs   for     the Reporting Period  .     (h)     Foreign   e  xchange'),
# ...
#  Document(metadata={}, page_content='determines that a sufficient a  ggravating factor(s) exist, in   which case it shall impose a Minor'),
#  Document(metadata={}, page_content='impose a Minor Sporting Penalty in addition to the Financial Penalty, or   in lieu of the Financial'),
#  Document(metadata={}, page_content='of the Financial Penalty.     Late and Non  -  Submission     of Full Year Reporting Documentation'),
#  Document(metadata={}, page_content='Documentation     8.4     In the event that a     Power Unit Manufacturer     does not submit the'),
#  Document(metadata={}, page_content='not submit the   Full Year   Reporting   Documentation by the   Full Year   Reporting Deadline (a'),
#  Document(metadata={}, page_content='Deadline (a   "  Late Submission  "  ), the Cost Cap   Administration     shall issue a late'),
#  Document(metadata={}, page_content='shall issue a late submission notice (  "  Late Submission Notice  "  ) to the   Power   Unit'),
#  Document(metadata={}, page_content='the   Power   Unit Manufact  urer     (the   "  Late Submitting   Manufacturer  "  ).     8.5'),
#  Document(metadata={}, page_content='"  ).     8.5     Each Late Submitting   Manufacturer     shall, within   48     hours of receipt'),
#  Document(metadata={}, page_content='hours of receipt of the Late Submission   Notice,   provide   the Cost Cap   Administration'),
#  Document(metadata={}, page_content='Administration     with a written explanation of   the reasons for its   Late Submission  .'),
#  Document(metadata={}, page_content='Submission  .      8.6     The Cost C  ap   Administration     may     grant the Late Submitting'),
#  Document(metadata={}, page_content='Late Submitting   Manufacturer     an extension to the   Full Year   Reporting Deadline'),
#  Document(metadata={}, page_content='Deadline     provided that it is satisfied with the written explanation pursuant   to Article   8.5'),
#  Document(metadata={}, page_content='to Article   8.5     (the   "  Extended   Reporting   Deadline  "  )  .     8.7     In the event'),
#  Document(metadata={}, page_content='In the event that     a Late Submitting   Manufacturer  :      (a)     does not   provide a'),
#  Document(metadata={}, page_content='not   provide a written response   to a Late Submission Notice   within the specified   time'),
#  Document(metadata={}, page_content='time              Formula 1 Power Unit Financial Regulations     25     16 August     2022     ©'),
#  Document(metadata={}, page_content='2022     © 202  2                Issue   1           (b)     provide  s     a written response'),
#  Document(metadata={}, page_content='a written response to a Late Submission     Notice     within the specified time   but   such'),
#  Document(metadata={}, page_content='time   but   such response   is deemed unsatisfactory by the Cost Cap Administration      or'),
#  Document(metadata={}, page_content='or      (c)     does not submit the   Full Year   Reporting Documentation by the Extended'),
#  Document(metadata={}, page_content='by the Extended   Reporting   Deadline,      the Late Sub  mitting   Manufacturer     shall have'),
#  Document(metadata={}, page_content='shall have committed a Non  -  Submission Breach and shall   be immediately referred to the'),
#  Document(metadata={}, page_content='referred to the Cost Cap Adjudication Panel.     8.8     A     Power Unit Manufacturer     that'),
#  Document(metadata={}, page_content='that submits a Subset Cost Cap Reporting Template as part of its   Full Year Reporting'),
#  Document(metadata={}, page_content='Full Year Reporting Documenta  tion   when     such   Power Unit Manufacturer     has     failed to'),
#  Document(metadata={}, page_content='has     failed to meet   the applicable deadlines     in order to use     Subset Accounts'),
#  Document(metadata={}, page_content='Subset Accounts stipulated by the Cost Cap   Administration via   a   Determination shall have'),
#  Document(metadata={}, page_content='shall have committed a Non  -  Submission Breach.      8.9     In the event the Cost Cap'),
#  Document(metadata={}, page_content='the Cost Cap   Adjudication Panel determines that a     Power Unit Manufacturer     has   committed'),
#  Document(metadata={}, page_content='has   committed     a Non  -  Submission Breach, the Cost Cap Adjudication Panel shall impose a'),
#  Document(metadata={}, page_content='shall impose a        in accordance with Article     9.1(c)(i)   and   additionally   may impose'),
#  Document(metadata={}, page_content='may impose   a Financial Penalty   and/or any   other   Material Sporting Penalties  .     Minor'),
#  Document(metadata={}, page_content='.     Minor Overspend Breach     8.10     A "  Minor Overspend Breach  " arise  s     when:'),
#  Document(metadata={}, page_content='s     when:     (a)     a     Power Unit Manufacturer     submits its Full Year Reporting'),
#  Document(metadata={}, page_content='Full Year Reporting Documentation and   Relevant Costs   reported therein   exceed the   Power Unit'),
#  Document(metadata={}, page_content='the   Power Unit   Cost Cap by   less     than 5%  or     (b)     f  ollowing the review of a'),
#  Document(metadata={}, page_content='the review of a     Power Unit Manufacturer    Documentation (including, where applicable, the'),
#  Document(metadata={}, page_content='applicable, the conclusion of any   investigation   undertaken by the Cost Cap   Administration'),
#  Document(metadata={}, page_content='Administration     and/or the Independent Audit Firm   appointed by the Cost Cap   Administration'),
#  Document(metadata={}, page_content='Administration  ),     the   Power Unit Manufacturer    Relevant   Costs have been   determined'),
#  Document(metadata={}, page_content='been   determined   to exceed the   Power Unit   Cost Cap by   less     than 5%.     8.11     In'),
#  Document(metadata={}, page_content='5%.     8.11     In the event the Cost Cap Adjudication Panel determines that   a     Power Unit'),
#  Document(metadata={}, page_content='a     Power Unit Manufacturer     has   committed     a Minor Overspend Breach, the Cost Cap'),
#  Document(metadata={}, page_content='the Cost Cap Adjudication Panel   may   impose a   Financial Penalty and/or a  ny Minor Sporting'),
#  Document(metadata={}, page_content='ny Minor Sporting Penalties  .     Material Overspend Breach     8.12     A "  Material Overspend'),
#  Document(metadata={}, page_content='Material Overspend Breach  " arise  s     when:     (a)     a     Power Unit Manufacturer'),
#  Document(metadata={}, page_content='Manufacturer     submits its Full Year Reporting Documentation and   Relevant Costs     reported'),
#  Document(metadata={}, page_content='Costs     reported therein     exceed the   Power Unit   Cost Cap by   5%     or more    or     (b)'),
#  Document(metadata={}, page_content='more    or     (b)     f  ollowing the review of a     Power Unit Manufacturer    Documentation'),
#  Document(metadata={}, page_content='Documentation (including, wh  ere applicable, the conclusion of any   investigation   undertaken'),
#  Document(metadata={}, page_content='undertaken by the Cost Cap   Administration     and/or the Independent Audit Firm   appointed by'),
#  Document(metadata={}, page_content='Firm   appointed by the Cost Cap   Administration  ),     the   Power Unit Manufacturer    Relevant'),
#  Document(metadata={}, page_content='Relevant   Costs have been   determined   to exceed the   Power     Unit   Cost Cap by   5%'),
#  Document(metadata={}, page_content='Cap by   5%     or more  .     8.13     In the event the Cost Cap Adjudication Panel determines'),
#  Document(metadata={}, page_content='Panel determines that   a Power Unit Manufacturer   has   committed     a Material Overspend'),
#  Document(metadata={}, page_content='Material Overspend Breach, the Cost Cap Adjudication Panel shall impose a        Formula 1 Power'),
#  Document(metadata={}, page_content='Formula 1 Power Unit Financial Regulations     26     16 August     2022     © 202  2'),
#  Document(metadata={}, page_content='© 202  2                Issue   1                in accordance with Article     9.1(c)(i)   and'),
#  Document(metadata={}, page_content='9.1(c)(i)   and   additionally   may impose a Financial Penalty and/  or   any   other   Material'),
#  Document(metadata={}, page_content='other   Material Sporting Penalt  ies  .     Aggravating or mitigating factors     8.14     In'),
#  Document(metadata={}, page_content='8.14     In determining the sanctions appropriate for a particular case,     the Cost Cap'),
#  Document(metadata={}, page_content='the Cost Cap Adjudication   Panel   shall take into account any aggravating or mitigating'),
#  Document(metadata={}, page_content='or mitigating factors.      8.15     Examples of aggravating factors include:     (a)     any e'),
#  Document(metadata={}, page_content='(a)     any e  lement of   bad faith,   dishonesty, wilful concealment or fraud      (b)     m'),
#  Document(metadata={}, page_content='(b)     m  ultiple breaches of the  se     Power Unit   Financial Regulations     in   the'),
#  Document(metadata={}, page_content='in   the Reporting   Period     in question        (c)     breaches of these   Power Unit'),
#  Document(metadata={}, page_content='Power Unit   Financial Regulations in respect of a previous Reporting   Period      (d)     q'),
#  Document(metadata={}, page_content='(d)     q  uantum of breach of the   Power Unit   Cost Cap    and     (e)     f  ailure to co'),
#  Document(metadata={}, page_content='f  ailure to co  -  operate with     the Cost Cap   Administration     and/or Independent Audit'),
#  Document(metadata={}, page_content='Independent Audit Firm     appoint  ed by the Cost Cap   Administration  .     8.16     Examples of'),
#  Document(metadata={}, page_content='Examples of mitigating factors include:     (a)     voluntary disclosure of a breach   to the'),
#  Document(metadata={}, page_content='a breach   to the Cost Cap   Administration        (b)     t  rack record of compliance with the'),
#  Document(metadata={}, page_content='with the  se     Power Unit   Financial Regulations     in previous   Reporting P  eriods      (c)'),
#  Document(metadata={}, page_content='P  eriods      (c)     u  nforeseen Force Majeure Events    and     (d)     f  ull and unfettered'),
#  Document(metadata={}, page_content='and unfettered   co  -  operation     with     the   Cost Cap   Administration     and/or   the'),
#  Document(metadata={}, page_content='and/or   the   Independent Audit Firm     appointed by the Cost Cap   Administration  .     9.'),
#  Document(metadata={}, page_content='.     9.     SANCTIONS FOR BREACH     Sanctions     9.1     The following sanctions may be imposed'),
#  Document(metadata={}, page_content='may be imposed for breach of these   Power Unit   Financial Regulations     as set out in Article'),
#  Document(metadata={}, page_content='out in Article   8  :     (a)     A "  Financial Penalty  ", meaning     a fine     in an amount'),
#  Document(metadata={}, page_content='in an amount   to be determined on a case by   case basis  .     (b)     A "  Minor Sporting'),
#  Document(metadata={}, page_content='A "  Minor Sporting Penalty  ", meaning one or more of the following:     (i)     public reprimand'),
#  Document(metadata={}, page_content='public reprimand      (ii)     deduction of       points awarded to the Nominated Team of   the'),
#  Document(metadata={}, page_content='Team of   the relevant Power Unit      Formula 1 Power Unit Financial Regulations     27     16'),
#  Document(metadata={}, page_content='27     16 August     2022     © 202  2                Issue   1           Manufacturer for the'),
#  Document(metadata={}, page_content='for the Championship that took place within the Reporting   Period of the breach      (iii)'),
#  Document(metadata={}, page_content='(iii)     deduction of       points awarded to the Nominated Team and   to all     Customer'),
#  Document(metadata={}, page_content='to all     Customer Teams of the   relevant Power Unit Manufacturer for the Championship that took'),
#  Document(metadata={}, page_content='that took place   within the Reporting Period of the   breach      (iv)     l  imitations on   the'),
#  Document(metadata={}, page_content='on   the   ability t  o   conduct   Power Unit Test Bench   testing   or other   T  esting     in'),
#  Document(metadata={}, page_content='T  esting     in respect of Power Units   to be   homologated for supply to   F1 Teams   in'),
#  Document(metadata={}, page_content='to   F1 Teams   in respect of the Championships taking place from 2026 onwards        and/  or'),
#  Document(metadata={}, page_content='and/  or     (v)     r  eduction of the   Power Unit   Cost Cap,     provided that     the'),
#  Document(metadata={}, page_content='that     the penalty specified in Article     9.1(b)  (v)     shall only   be applied   with'),
#  Document(metadata={}, page_content='be applied   with   respect   to   the   Full Year Reporting Period   immediately     following the'),
#  Document(metadata={}, page_content='following the   date of the   imposition of the sanction     (and subsequent   Full Year'),
#  Document(metadata={}, page_content='Full Year Reporting Periods  , where   applicable)    and     provided that the penalties'),
#  Document(metadata={}, page_content='that the penalties specified in     Articles 9.1(b)(ii)   and   9.1(b)(iii) can  not   be   applied'),
#  Document(metadata={}, page_content='not   be   applied   prior to 1 January 2026  .     (c)     A "  Material   Sporting Penalty  ",'),
#  Document(metadata={}, page_content='Penalty  ", meaning one or more of the following:     (i)     deduction of       points awarded to'),
#  Document(metadata={}, page_content='points awarded to the Nominated Team of the relevant Power Unit   Manufacturer for the'),
#  Document(metadata={}, page_content='for the Championship that took place within the Repor  ting   Period of the breach      (ii)'),
#  Document(metadata={}, page_content='(ii)     deduction of       points awarded to the Nominated Team and to all Customer Teams of'),
#  Document(metadata={}, page_content='Customer Teams of the   relevant Power Unit Manufacturer for the Championship that took place'),
#  Document(metadata={}, page_content='that took place   within the Reporting     Period of the breach      (iii)     l  imitations on the'),
#  Document(metadata={}, page_content='imitations on the ability to conduct     Power Unit Test Bench   testing     or other   T  esting'),
#  Document(metadata={}, page_content='other   T  esting     in respect of Power Units to be homologated for supply to F1 Teams   in'),
#  Document(metadata={}, page_content='to F1 Teams   in respect of the Championships taking place from 2026 onwards        (iv)'),
#  Document(metadata={}, page_content='(iv)     limitations on the ability to make future upgrades to the specification of the'),
#  Document(metadata={}, page_content='of the   Power Unit   that is currently   homologated     for supply to F1 Teams        (v)'),
#  Document(metadata={}, page_content='(v)     divesting of right for its Power Units to be homologated for supply to F1 Teams   in'),
#  Document(metadata={}, page_content='to F1 Teams   in respect of any Championship s  easons from 2026 onwards        or     (vi)     r'),
#  Document(metadata={}, page_content='or     (vi)     r  eduction of the   Power Unit   Cost Cap,     provided that     the penalty'),
#  Document(metadata={}, page_content='the penalty specified in Article     9.1(c)  (v  i  )     shall only   be applied   with'),
#  Document(metadata={}, page_content='be applied   with   respect to   the   Full Year Reporting     Period   immediately     following'),
#  Document(metadata={}, page_content='following the     date of the     imposition of the sanction     (and subsequent   Full Year'),
#  Document(metadata={}, page_content='Full Year Reporting Periods  , where   applicable  )    and        Formula 1 Power Unit Financial'),
#  ...]

# %% [markdown]
# Acabamos de realizar algunas fragmentaciones utilizando Langchain, un framework popular para crear aplicaciones utilizando modelos de lenguaje grandes. En los métodos anteriores, viste varios ejemplos de chunking. Langchain puede ayudar a hacer que el proceso de chunking sea más fácil con algunos de sus métodos. Estos métodos incluyen fragmentos de tamaño fijo, así como la fragmentación recursiva, que acabamos de ver.
#
# Por ejemplo, existe `CharacterTextSplitter` que dividirá el texto dado en un fragmento de tamaño fijo de un tamaño determinado y una superposición de caracteres determinada.
#
# `RecursiveCharacterTextSplitter` divide el texto en fragmentos más pequeños de manera iterativa. Nuevamente, puedes proporcionar el tamaño del fragmento y el recuento de superposición del fragmento.

# %% [markdown]
# La segmentación es una técnica importante por muchas razones. Ayuda a evitar el límite de tokens cuando se trabaja con grandes cantidades de datos y también optimiza la respuesta que recibimos del modelo. Encontrar la técnica de segmentación adecuada y el tamaño de fragmento es crucial para recibir respuestas relevantes.

# %% [markdown]
# ## Criterios de Éxito
#
# Para completar este desafío con éxito:
#
# * Demuestra una comprensión de los tokens y cómo calcularlos.
# * Demuestra una comprensión de la segmentación (chunking) experimentando con diferentes técnicas.
# * Sé capaz de entender la importancia de encontrar la solución de segmentación adecuada según si se captura o no el significado semántico.
